# %%
import pandas as pd

df = pd.read_csv("fatal-police-shootings-data (3).csv")
df
# Out:
#         id                name        date   manner_of_death         armed  \
# 0        3          Tim Elliot  2015-01-02              shot           gun
# 1        4    Lewis Lee Lembke  2015-01-02              shot           gun
# 2        5  John Paul Quintero  2015-01-03  shot and Tasered       unarmed
# 3        8     Matthew Hoffman  2015-01-04              shot    toy weapon
# 4        9   Michael Rodriguez  2015-01-04              shot      nail gun
# ...    ...                 ...         ...               ...           ...
# 5411  5921      William Slyter  2020-06-13              shot           gun
# 5412  5922               TK TK  2020-06-13              shot  undetermined
# 5413  5924      Nicholas Hirsh  2020-06-15              shot           gun
# 5414  5926               TK TK  2020-06-16              shot           gun
# 5415  5927               TK TK  2020-06-16              shot           gun
#
#        age gender race            city state  signs_of_mental_illness  \
# 0     53.0      M    A         Shelton    WA                     True
# 1     47.0      M    W           Aloha    OR                    False
# 2     23.0      M    H         Wichita    KS                    False
# 3     32.0      M    W   San Francisco    CA                     True
# 4     39.0      M    H           Evans    CO                    False
# ...    ...    ...  ...             ...   ...                      ...
# 5411  22.0      M    W     Kansas City    MO                    False
# 5412   NaN      M  NaN  San Bernardino    CA                    False
# 5413  31.0      M    W        Lawrence    KS                    False
# 5414  24.0      M  NaN      Beach Park    IL                    False
# 5415  27.0      M  NaN         Phoenix    AZ                    False
#
#      threat_level         flee  body_camera
# 0          attack  Not fleeing        False
# 1          attack  Not fleeing        False
# 2           other  Not fleeing        False
# 3          attack  Not fleeing        False
# 4          attack  Not fleeing        False
# ...           ...          ...          ...
# 5411        other        Other        False
# 5412       attack  Not fleeing        False
# 5413       attack          Car        False
# 5414       attack  Not fleeing        False
# 5415       attack  Not fleeing        False
#
# [5416 rows x 14 columns]

# %%
table = df.groupby(["race","signs_of_mental_illness"]).size().unstack()
table
# Out:
# signs_of_mental_illness  False  True
# race
# A                           69     24
# B                         1114    184
# H                          745    157
# N                           64     14
# O                           37     11
# W                         1763    713

# %%
table["percent"]  = table.apply(
lambda row: row[True] / (row[True] + row[False]) * 100, axis=1 
)
table
# Out:
# signs_of_mental_illness  False  True    procent
# race
# A                           69    24  25.806452
# B                         1114   184  14.175655
# H                          745   157  17.405765
# N                           64    14  17.948718
# O                           37    11  22.916667
# W                         1763   713  28.796446

# %%
# Out:
# Index([False, True], dtype='bool', name='signs_of_mental_illness')

# %%
df["date"] = pd.to_datetime(df["date"])
df["weekday"] = df["date"].dt.day_name()
orders = ["Monday","Thusday","Wendsay","Friday","Saturday","Sunday"]
df["weekday"] = pd.Categorical(df["weekday"], categories=orders, ordered=True)
counts = df["weekday"].value_counts().sort_index()
counts
# Out:
# weekday
# Monday      726
# Thusday       0
# Wendsay       0
# Friday      761
# Saturday    721
# Sunday      753
# Name: count, dtype: int64

# %%
counts.plot(kind="bar")
# Out:
# <Axes: xlabel='weekday'>

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~\miniconda3\Lib\site-packages\pandas\compat\_optional.py:135, in import_optional_dependency(name, extra, errors, min_version)
#     134 try:
# --> 135     module = importlib.import_module(name)
#     136 except ImportError:
#
# File ~\miniconda3\Lib\importlib\__init__.py:90, in import_module(name, package)
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1310, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:488, in _call_with_frames_removed(f, *args, **kwds)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1324, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'lxml'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[45], line 2
#       1 url = "https://en.wikipedia.org/wiki/List_of_states_and_territories_of_the_United_States_by_population"
# ----> 2 list_us = pd.read_html(url)
#       3 list_us
#
# File ~\miniconda3\Lib\site-packages\pandas\io\html.py:1240, in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only, extract_links, dtype_backend, storage_options)
#    1224 if isinstance(io, str) and not any(
#    1225     [
#    1226         is_file_like(io),
#    (...)   1230     ]
#    1231 ):
#    1232     warnings.warn(
#    1233         "Passing literal html to 'read_html' is deprecated and "
#    1234         "will be removed in a future version. To read from a "
#    (...)   1237         stacklevel=find_stack_level(),
#    1238     )
# -> 1240 return _parse(
#    1241     flavor=flavor,
#    1242     io=io,
#    1243     match=match,
#    1244     header=header,
#    1245     index_col=index_col,
#    1246     skiprows=skiprows,
#    1247     parse_dates=parse_dates,
#    1248     thousands=thousands,
#    1249     attrs=attrs,
#    1250     encoding=encoding,
#    1251     decimal=decimal,
#    1252     converters=converters,
#    1253     na_values=na_values,
#    1254     keep_default_na=keep_default_na,
#    1255     displayed_only=displayed_only,
#    1256     extract_links=extract_links,
#    1257     dtype_backend=dtype_backend,
#    1258     storage_options=storage_options,
#    1259 )
#
# File ~\miniconda3\Lib\site-packages\pandas\io\html.py:971, in _parse(flavor, io, match, attrs, encoding, displayed_only, extract_links, storage_options, **kwargs)
#     969 retained = None
#     970 for flav in flavor:
# --> 971     parser = _parser_dispatch(flav)
#     972     p = parser(
#     973         io,
#     974         compiled_match,
#    (...)    979         storage_options,
#     980     )
#     982     try:
#
# File ~\miniconda3\Lib\site-packages\pandas\io\html.py:918, in _parser_dispatch(flavor)
#     916     import_optional_dependency("bs4")
#     917 else:
# --> 918     import_optional_dependency("lxml.etree")
#     919 return _valid_parsers[flavor]
#
# File ~\miniconda3\Lib\site-packages\pandas\compat\_optional.py:138, in import_optional_dependency(name, extra, errors, min_version)
#     136 except ImportError:
#     137     if errors == "raise":
# --> 138         raise ImportError(msg)
#     139     return None
#     141 # Handle submodules: if we have submodule, grab parent module from sys.modules
#
# ImportError: Missing optional dependency 'lxml'.  Use pip or conda to install lxml.

# %%
# !python -m pip install lxml
# Out:
# Collecting lxml
#   Downloading lxml-6.0.2-cp313-cp313-win_amd64.whl.metadata (3.7 kB)
# Downloading lxml-6.0.2-cp313-cp313-win_amd64.whl (4.0 MB)
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/4.0 MB ? eta -:--:--
#    -------------------- ------------------- 2.1/4.0 MB 7.5 MB/s eta 0:00:01
#    ------------------------------------ --- 3.7/4.0 MB 7.6 MB/s eta 0:00:01
#    ---------------------------------------- 4.0/4.0 MB 7.3 MB/s  0:00:00
# Installing collected packages: lxml
# Successfully installed lxml-6.0.2

# %%
url = "https://en.wikipedia.org/wiki/List_of_states_and_territories_of_the_United_States_by_population"
list_us = pd.read_html(url)
list_us
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~\miniconda3\Lib\site-packages\pandas\compat\_optional.py:135, in import_optional_dependency(name, extra, errors, min_version)
#     134 try:
# --> 135     module = importlib.import_module(name)
#     136 except ImportError:
#
# File ~\miniconda3\Lib\importlib\__init__.py:90, in import_module(name, package)
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1310, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:488, in _call_with_frames_removed(f, *args, **kwds)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1324, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'lxml'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[50], line 2
#       1 url = "https://en.wikipedia.org/wiki/List_of_states_and_territories_of_the_United_States_by_population"
# ----> 2 list_us = pd.read_html(url)
#       3 list_us
#
# File ~\miniconda3\Lib\site-packages\pandas\io\html.py:1240, in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only, extract_links, dtype_backend, storage_options)
#    1224 if isinstance(io, str) and not any(
#    1225     [
#    1226         is_file_like(io),
#    (...)   1230     ]
#    1231 ):
#    1232     warnings.warn(
#    1233         "Passing literal html to 'read_html' is deprecated and "
#    1234         "will be removed in a future version. To read from a "
#    (...)   1237         stacklevel=find_stack_level(),
#    1238     )
# -> 1240 return _parse(
#    1241     flavor=flavor,
#    1242     io=io,
#    1243     match=match,
#    1244     header=header,
#    1245     index_col=index_col,
#    1246     skiprows=skiprows,
#    1247     parse_dates=parse_dates,
#    1248     thousands=thousands,
#    1249     attrs=attrs,
#    1250     encoding=encoding,
#    1251     decimal=decimal,
#    1252     converters=converters,
#    1253     na_values=na_values,
#    1254     keep_default_na=keep_default_na,
#    1255     displayed_only=displayed_only,
#    1256     extract_links=extract_links,
#    1257     dtype_backend=dtype_backend,
#    1258     storage_options=storage_options,
#    1259 )
#
# File ~\miniconda3\Lib\site-packages\pandas\io\html.py:971, in _parse(flavor, io, match, attrs, encoding, displayed_only, extract_links, storage_options, **kwargs)
#     969 retained = None
#     970 for flav in flavor:
# --> 971     parser = _parser_dispatch(flav)
#     972     p = parser(
#     973         io,
#     974         compiled_match,
#    (...)    979         storage_options,
#     980     )
#     982     try:
#
# File ~\miniconda3\Lib\site-packages\pandas\io\html.py:918, in _parser_dispatch(flavor)
#     916     import_optional_dependency("bs4")
#     917 else:
# --> 918     import_optional_dependency("lxml.etree")
#     919 return _valid_parsers[flavor]
#
# File ~\miniconda3\Lib\site-packages\pandas\compat\_optional.py:138, in import_optional_dependency(name, extra, errors, min_version)
#     136 except ImportError:
#     137     if errors == "raise":
# --> 138         raise ImportError(msg)
#     139     return None
#     141 # Handle submodules: if we have submodule, grab parent module from sys.modules
#
# ImportError: Missing optional dependency 'lxml'.  Use pip or conda to install lxml.

# %%
import sys
sys.executable
# Out:
# 'C:\\Users\\biedn\\miniconda3\\python.exe'

# %%
# !python -m pip install html5lib
# Out:
# Collecting html5lib
#   Downloading html5lib-1.1-py2.py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: six>=1.9 in c:\users\biedn\appdata\local\programs\python\python313\lib\site-packages (from html5lib) (1.17.0)
# Requirement already satisfied: webencodings in c:\users\biedn\appdata\local\programs\python\python313\lib\site-packages (from html5lib) (0.5.1)
# Downloading html5lib-1.1-py2.py3-none-any.whl (112 kB)
# Installing collected packages: html5lib
# Successfully installed html5lib-1.1

# %%
# !python -m pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in c:\users\biedn\appdata\local\programs\python\python313\lib\site-packages (4.14.2)
# Requirement already satisfied: soupsieve>1.2 in c:\users\biedn\appdata\local\programs\python\python313\lib\site-packages (from beautifulsoup4) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\biedn\appdata\local\programs\python\python313\lib\site-packages (from beautifulsoup4) (4.15.0)

# %%
# !conda install lxml -y
# Out:
# 'conda' is not recognized as an internal or external command,
# operable program or batch file.
